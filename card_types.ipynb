# %%
#Read 'standard_cards.csv' from the data folder into a pandas dataframe
#Print the first 5 rows of the dataframe

import pandas as pd

df = pd.read_csv('/mnt/data/standard_cards.csv')
print(df.head(5))
# Out:
#                                    uuid number                name set code  \
# 0  6ff98307-b89c-5a43-bc3c-3f81d803617d      1    Aeronaut Cavalry      BRO
# 1  e4d66ec1-7ba2-5c80-a9c1-e33500cfdbb5      2    Airlift Chaplain      BRO
# 2  8d065ec5-4e7f-50f6-92c8-277673a6fb19      3  Ambush Paratrooper      BRO
# 3  45e16536-c429-54c9-906e-43b9f9ee83b2      4     Calamity's Wake      BRO
# 4  d184bcd7-1c35-558f-8fd4-c2065a349018      5      Deadly Riposte      BRO
#
#                                                 text mana cost  mana value  \
# 0  Flying\nWhen Aeronaut Cavalry enters the battl...    {4}{W}         5.0
# 1  Flying\nWhen Airlift Chaplain enters the battl...    {2}{W}         3.0
# 2  Flash\nFlying\n{5}: Creatures you control get ...    {1}{W}         2.0
# 3  Exile all graveyards. Players can't cast noncr...    {1}{W}         2.0
# 4  Deadly Riposte deals 3 damage to target tapped...    {1}{W}         2.0
#
# ...

# %%
#Filter all cards that have the Type 'Planeswalker'

planeswalkers = df[df['type'].str.contains('Planeswalker')]
print(planeswalkers)
# Out:
#                                       uuid number  \
# 67    835faa90-e4a1-5564-a88e-6b61c63f70d8     66
# 227   afc2ada3-6503-526b-9797-66372368c1a5    219
# 228   fdbabaf0-9197-53c7-a101-813c7543dba0  A-219
# 248   286fd366-82c8-5948-8101-d10bcf67fbf1   238b
# 287   c55d896f-66d1-5e26-ac69-049d5d996a75      1
# 288   6cf47485-30b9-578e-8c87-3378ae11e7a4    A-1
# 384   039c2d6f-6647-5d1a-941a-5b838412c7df     97
# 420   b797ce1d-974d-59cc-b407-91081e35a039    133
# 486   d001f781-541d-5a02-a4d6-374e6c2b5bd1    192
# 806   c5604d70-ed5e-55fe-b987-d86371b0fb0a    238
# 1119  4fa35034-d0dc-5335-945a-1b08388e663a    208
# 1122  7450d1d0-1622-5a70-b874-a5464b530be6    211
# 1157  39c5ef1d-b358-539e-b3fc-41573cc30c04    245
# 1389  c6a4a427-8945-5d64-8236-d8ea1146bd77    211
# 1458  6b4e232f-3750-5754-8397-0549d3f50e2a      6
# 1585  d461f6df-e724-514e-adf2-620f1db0a694    134
# 1668  c7c4e1f7-fb55-55f9-9604-27fbb5207e20    217
# 1787  ba3bc840-d81c-5f26-afb7-c81460a512ae     42
# ...

# %%
Enchantments = df[df['type'].str.contains('Enchantment')]  
print(Enchantments)
# Out:
#                                       uuid number                   name  \
# 7     ada20bab-ada6-5bed-9d45-d87790233c25      8        In the Trenches
# 15    8c24486d-4d6b-5c3e-a78a-26057db06745     16  Meticulous Excavation
# 16    082e9de2-d7d0-59d7-8dbf-c7bf8a8509ad     17    Military Discipline
# 20    047b6ef3-a654-5d6c-8378-057d3555c403     21        Prison Sentence
# 26    09371945-5baf-5ec4-8f9c-7836bfe41789     27             Static Net
# ...                                    ...    ...                    ...
# 2930  ff8f8e14-ce8f-5664-82fb-abbd82b428b0     58         Parallel Lives
# 2931  30a77dff-df73-5272-9958-d2e6c76c1cf1     59           Primal Vigor
# 2932  68426b9f-69a8-5b61-ab87-e79f4d2a7d6a     60         Prismatic Omen
# 2933  18882c76-ad57-5da3-bf35-eb59c9d1a18a     61       Season of Growth
# 2934  e5c411ba-b41a-5c94-aa41-9307e41556b7     63          Utopia Sprawl
#
#      set code                                               text  mana cost  \
# ...

# %%
Creatures = df[df['types'].str.contains('Creature')]

# %%
Sorceries = df[df['types'].str.contains('Sorcery')]

# %%
Instants = df[df['types'].str.contains('Instant')]

# %%
Lands = df[df['types'].str.contains('Land')]

# %%
Artifacts = df[df['types'].str.contains('Artifact')]
